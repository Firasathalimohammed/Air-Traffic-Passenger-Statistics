# %% [markdown]
# <a id="2"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>✈️ Air Traffic Analysis ✈️</b></div>

# %% [markdown]
# ----

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b> 🎬 Introduction 🎬</b></div>

# %% [markdown]
# <div style="border-radius:10px;border:black solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:17px">
#
#
#
# <h3 align="left"><font color=purple>📝 Brief Summary of Data:</font></h3><br>
#
#
# * The "<b>Air Traffic Passenger Data</b>" dataset provides insights into <b>air travel activities</b> and <b>passenger information</b>. <br>
#     <br>
# * It includes records for both domestic and international flights, featuring details on <b>operating and published airlines</b>, <b>geographical regions</b>, <b>passenger counts</b>, and more. <br>
#     <br>
# * The dataset is organized into columns that describe key attributes, such as the <b>activity period</b>, <b>airline details</b>, <b>geographical information</b>, <b>activity type</b>, and <b>price categories</b>. <br>
#     <br>
# * This dataset is a valuable resource for <b>researchers and analysts</b> interested in understanding <b>air traffic trends</b>, <b>passenger movement</b>, and <b>airline operations</b>. <br>
#     <br>
# * It offers opportunities to explore patterns in <b>air travel</b>, evaluate <b>airline performance</b>, and gain insights into <b>passenger preferences</b>. <br>
# <br>
# * This data from the data.gov website. You can access the dataset at the following link:
#     <a href="https://catalog.data.gov/dataset/air-traffic-passenger-statistics">Air Traffic Passenger Statistics</a>
#
#
#     <br>
#     <br>
#
#
# <h3 align="left"><font color=purple>📝 Research Questions:</font></h3><br>
#
# *  What is the trend in <b>passenger traffic</b> over time, and are there any seasonal patterns in <b>air travel activity</b>?<br>
# <br>
# * How do different <b>airlines</b> compare in terms of <b>passenger counts</b>, and are there any significant variations between <b>domestic and international flights</b>?
# <br>
# <br>
# * Are there specific geographic regions or <b>airports</b> that show a notable increase in <b>passenger traffic</b>, and what factors might contribute to these variations?
# <br>
# <br>
# * What is the relationship between <b>airfare price categories</b> and <b>passenger counts</b>, and does <b>low-fare pricing</b> significantly impact <b>passenger numbers</b>?
# <br>
# <br>
# * Which are the <b>Top 5 GEO Region</b> according to the Datase.<br></div>

# %% [markdown]
# ---

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b> 📚 Importing Libraries 📚</b></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
sns.set(style="darkgrid",font_scale=1.5)

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>⏳ Loading Datset ⏳</b></div>

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\Air_Traffic_Passenger_Statistics.csv")
df.head()
# Out:
#    Activity Period Activity Period Start Date  \
# 0           199907                 1999/07/01
# 1           199907                 1999/07/01
# 2           199907                 1999/07/01
# 3           199907                 1999/07/01
# 4           199907                 1999/07/01
#
#                          Operating Airline Operating Airline IATA Code  \
# 0                             ATA Airlines                          TZ
# 1                             ATA Airlines                          TZ
# 2                             ATA Airlines                          TZ
# 3  Aeroflot Russian International Airlines                         NaN
# 4  Aeroflot Russian International Airlines                         NaN
#
#                          Published Airline Published Airline IATA Code  \
# 0                             ATA Airlines                          TZ
# 1                             ATA Airlines                          TZ
# ...

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>🧾 Features Description 🧾</b></div>

# %% [markdown]
# | S.No | Attribute Name                | Meaning                                           |
# |------|------------------------------|---------------------------------------------------|
# | 1    | Activity Period               | The period or month of the recorded activity     |
# | 2    | Activity Period Start Date    | The start date of the activity period             |
# | 3    | Operating Airline             | The name of the airline operating the flight     |
# | 4    | Operating Airline IATA Code   | The IATA code (2-letter code) for the operating airline |
# | 5    | Published Airline             | The name of the airline as published              |
# | 6    | Published Airline IATA Code   | The IATA code for the published airline            |
# | 7    | GEO Summary                   | A summary of the geographical region (e.g., Domestic, International) |
# | 8    | GEO Region                    | The specific geographical region or location      |
# | 9    | Activity Type Code            | The type of activity (e.g., Deplaned, Enplaned, Thru / Transit) |
# | 10   | Price Category Code           | The price category (e.g., Low Fare)                |
# | 11   | Terminal                      | The terminal associated with the activity         |
# | 12   | Boarding Area                 | The boarding area within the terminal              |
# | 13   | Passenger Count               | The number of passengers for the activity         |
# | 14   | data_as_of                    | The date and time when the data was recorded      |
# | 15   | data_loaded_at                | The date and time when the data was loaded         |

# %% [markdown]
# ---

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>📊 Data Summary. 📊</b></div>

# %% [markdown]
# ### 1. Computing the Dimension of Dataset.

# %%
df.shape
# Out:
# (34734, 15)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>💬 Inference:</font></h3>
#
# 1. There are total <b>34734 Records/Rows</b> in the dataset.<br>
# 2. There are total <b>15 Features/columns</b> in the dataset.<br></div>

# %% [markdown]
# ### 2. Generating Basic Information of Attributes.

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34734 entries, 0 to 34733
# Columns: 15 entries, Activity Period to data_loaded_at
# dtypes: int64(2), object(13)
# memory usage: 4.0+ MB

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. There are only <b>2 Numerical Attributes</b> in the dataset.<br>
# 2. On the other hand we have <b>13 Categorical Attributes.</b><br></div>

# %% [markdown]
# ### 3. Checking if There's Any Duplicate Records.

# %%
have_duplicate_rows = df.duplicated().any()
have_duplicate_rows
# Out:
# False

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. Since the <b>output is False, we can say that there's No Duplicate</b> Records present in the Dataset.<br></div>

# %% [markdown]
# ### 4. Checking Data-Types of Features.

# %%
df.dtypes.to_frame().rename(columns={0:"Data-Type"})
# Out:
#                             Data-Type
# Activity Period                 int64
# Activity Period Start Date     object
# Operating Airline              object
# Operating Airline IATA Code    object
# Published Airline              object
# Published Airline IATA Code    object
# GEO Summary                    object
# GEO Region                     object
# Activity Type Code             object
# Price Category Code            object
# Terminal                       object
# Boarding Area                  object
# Passenger Count                 int64
# data_as_of                     object
# data_loaded_at                 object

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. There are only <b>2 Numerical Attributes</b> in the dataset.<br>
# 2. On the other hand we have <b>13 Categorical Attributes.</b><br></div>

# %% [markdown]
# ### 5. Converting Data Type of Data Columns to DateTime.

# %%
df['Activity Period Start Date'] = pd.to_datetime(df['Activity Period Start Date'])

df['data_as_of'] = pd.to_datetime(df['data_as_of'])

df['data_loaded_at'] = pd.to_datetime(df['data_loaded_at'])

# %% [markdown]
# ### 6. Checking Unique Values of Categorical Attributes.

# %%
cat_cols = df.select_dtypes(include="O").columns

for column in cat_cols:
    print('No. of Unique values in', column,"is:",df[column].nunique())
    print("-"*127)
# Out:
# No. of Unique values in Operating Airline is: 134
# -------------------------------------------------------------------------------------------------------------------------------
# No. of Unique values in Operating Airline IATA Code is: 111
# -------------------------------------------------------------------------------------------------------------------------------
# No. of Unique values in Published Airline is: 121
# -------------------------------------------------------------------------------------------------------------------------------
# No. of Unique values in Published Airline IATA Code is: 100
# -------------------------------------------------------------------------------------------------------------------------------
# No. of Unique values in GEO Summary is: 2
# -------------------------------------------------------------------------------------------------------------------------------
# No. of Unique values in GEO Region is: 9
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. Starting <b>Four columns are having high cardinalities.</b><br>
# 2. All the others columns are having <b>low cardinality.</b>

# %% [markdown]
# ### 7. Computing Total No. of Missing Values and the Percentage of Missing Values.

# %%
missing_df = df.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing Values"})
missing_df["% of Missing Values"] = round((missing_df["Total No. of Missing Values"]/len(df))*100,2)
missing_df
# Out:
#                              Total No. of Missing Values  % of Missing Values
# Activity Period                                        0                 0.00
# Activity Period Start Date                             0                 0.00
# Operating Airline                                      0                 0.00
# Operating Airline IATA Code                          316                 0.91
# Published Airline                                      0                 0.00
# Published Airline IATA Code                          316                 0.91
# GEO Summary                                            0                 0.00
# GEO Region                                             0                 0.00
# Activity Type Code                                     0                 0.00
# Price Category Code                                    0                 0.00
# Terminal                                               0                 0.00
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. Some of the <b>Attributes are having Missing Values.</b><br>
# 2. But the Percentage Value of Missing Values are <b>very low</b> but we <b>can't compute missing values manuaaly</b> becuase all these datasets are raw datasets filling manually and <b>mislead our exploratory data analysis.</b><br></div>

# %% [markdown]
# ---

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>📊 Exploratory Data Analysis.📊</b></div>

# %% [markdown]
# ### 1. What is the trend in passenger traffic over time, and are there any seasonal patterns in air travel activity?

# %%
df['Activity Period Start Date'] = pd.to_datetime(df['Activity Period Start Date'])

passenger_traffic = df.groupby('Activity Period Start Date')['Passenger Count'].sum()

plt.figure(figsize=(12, 6))
plt.plot(passenger_traffic.index, passenger_traffic.values, marker='o', linestyle='-', color='b')
plt.title('Passenger Traffic Trend Over Time')
plt.xlabel('Activity Period')
plt.ylabel('Total Passenger Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. <b>Overall Increasing Trend</b>: Over the years from 1999 to 2023, there is a noticeable upward trend in <b>passenger traffic</b>. The total <b>passenger count</b> has generally increased, which indicates a growing demand for <b>air travel</b> over time.<br>
# <br>
# 2. <b>Seasonal Fluctuations</b>: The data exhibits <b>seasonal patterns</b>. There are periodic fluctuations in <b>passenger traffic</b>, with peaks during certain months and lower counts during others. These patterns may be attributed to factors such as holidays, vacations, or travel seasons.<br>
# <br>
# 3. <b>Recent Variations</b>: In recent years, especially in 2023, there seems to be a fluctuation in <b>passenger traffic</b>, with both increases and decreases in counts. This suggests that external factors like economic conditions, travel restrictions, or global events may impact <b>air travel</b> trends.<br>

# %% [markdown]
# ----

# %% [markdown]
# ### 2. How do different airlines compare in terms of passenger counts, and are there any significant variations between domestic and international flights?

# %%
passenger_counts = df.groupby(['Operating Airline', 'GEO Summary'])['Passenger Count'].sum().unstack()

top_5_domestic = passenger_counts['Domestic'].nlargest(5)
top_5_international = passenger_counts['International'].nlargest(5)

plt.figure(figsize=(12, 8))
top_5_domestic.plot(kind='bar', color='b', alpha=0.6, label='Domestic')
top_5_international.plot(kind='bar', color='g', alpha=0.6, label='International')
plt.title('Top 5 Airlines by Passenger Counts (Domestic vs. International)')
plt.xlabel('Operating Airline')
plt.ylabel('Total Passenger Count')
plt.legend(title='GEO Summary', title_fontsize='12')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# * The airline with the highest passenger count for domestic flights is "<b>United Airlines</b>" with a total of 166,103,646 passengers.<br>
# <br>
# * The second-ranking airline for domestic flights is "<b>United Airlines - Pre 07/01/2013</b>" with 159,578,077 passengers.
# "* <b>American Airlines</b>" is in third place with 74,729,337 passengers.<br>
# <br>
# "<b>SkyWest Airlines</b>" and "<b>Delta Air Lines</b>" occupy the fourth and fifth positions with 68,955,624 and 61,063,369 passengers, respectively.<br>
# <br>
# * "<b>United Airlines - Pre 07/01/2013</b>" is the leading airline for international flights with 40,042,459 passengers.<br>
# <br>
# * "<b>United Airlines</b>" takes the second position with 34,489,889 passengers.<br>
# <br>
# * "<b>Air Canada</b>" ranks third with 15,126,884 passengers.<br>
# <br>
# * "<b>Lufthansa German Airlines</b>" and "<b>British Airways</b>" secure the fourth and fifth spots with 10,055,167 and 9,368,317 passengers, respectively.<br>

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Are there specific geographic regions or airports that show a notable increase in passenger traffic, and what factors might contribute to these variations?

# %%
passenger_counts_by_region = df.groupby('GEO Region')['Passenger Count'].sum()

plt.figure(figsize=(8, 8))
plt.pie(passenger_counts_by_region, labels=passenger_counts_by_region.index, autopct='%1.f%%', startangle=140,
       textprops={"size":10,"fontweight":"black"})
plt.title('Passenger Counts by Geographic Region (Pie Chart)')
plt.axis('equal')
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# * The <b>US</b> is the dominant contributor to passenger traffic among all the <b>GEO Regions</b>, with a significantly higher total of <b>747,120,929</b> passengers. This suggests the substantial role the United States plays in air travel.<br>
# <br>
# * Among the other regions, <b>Asia</b> and <b>Europe</b> stand out as significant contributors to passenger counts, with <b>92,685,649</b> and <b>62,543,779</b> passengers, respectively. These regions also play a substantial role in international air travel.<br>
# <br>
# * In contrast, <b>South America</b> registers a comparatively lower passenger count of <b>250,822</b>. It indicates that air travel to and from South America may be less prominent compared to the other regions listed.<br>

# %% [markdown]
# ---

# %% [markdown]
# ### 4. What is the relationship between airfare price categories and passenger counts, and does low-fare pricing significantly impact passenger numbers?

# %%
df.head()
# Out:
#    Activity Period Activity Period Start Date  \
# 0           199907                 1999-07-01
# 1           199907                 1999-07-01
# 2           199907                 1999-07-01
# 3           199907                 1999-07-01
# 4           199907                 1999-07-01
#
#                          Operating Airline Operating Airline IATA Code  \
# 0                             ATA Airlines                          TZ
# 1                             ATA Airlines                          TZ
# 2                             ATA Airlines                          TZ
# 3  Aeroflot Russian International Airlines                         NaN
# 4  Aeroflot Russian International Airlines                         NaN
#
#                          Published Airline Published Airline IATA Code  \
# 0                             ATA Airlines                          TZ
# 1                             ATA Airlines                          TZ
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Price Category Code', y='Passenger Count', data=df, palette='Set2')
plt.title('Relationship between Airfare Price Categories and Passenger Counts')
plt.xlabel('Price Category Code')
plt.ylabel('Passenger Count')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# 1. Variability Across Price Categories: The box plot reveals that there is considerable variability in passenger counts across different airfare <b>price categories</b>. The boxes represent the <b>interquartile range</b>, and the whiskers show the spread of data, indicating that some <b>price categories</b> have a wider range of passenger counts than others.<br>
# <br>
#
# 2. Outliers and Extreme Values: The presence of <b>outliers</b> in the box plot indicates instances where <b>passenger counts</b> significantly deviate from the norm. These <b>outliers</b> might correspond to extraordinary circumstances or anomalies that need further investigation to understand their impact on <b>passenger numbers</b>.<br>

# %% [markdown]
# ---

# %% [markdown]
# ### 5. Which is the Top 5Geo Region according to the dataset.

# %%
passengers_by_region = df.groupby('GEO Region')['Passenger Count'].sum()

plt.figure(figsize=(12, 6))
passengers_by_region.plot(kind='bar', color='b', alpha=0.6)
plt.title('Passengers Traveling with Respect to GEO Region')
plt.xlabel('GEO Region')
plt.ylabel('Total Passenger Count')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Inference:</font></h3>
#
# * Significant Regional Disparities: The data reveals substantial disparities in the number of passengers traveling to different geographic regions. The <b>United States (US)</b> stands out as the dominant region, with an exceptionally high total of <b>747,120,929</b> passengers. This suggests that the <b>US</b> plays a pivotal role in air travel.<br>
# <br>
# * Key International Regions: Beyond the <b>US</b>, regions like <b>Asia</b> and <b>Europe</b> also draw noteworthy passenger counts, with <b>92,685,649</b> and <b>62,543,779</b> passengers, respectively. These regions are significant international destinations, attracting a substantial number of travelers.<br>
# <br>
# * Limited South American Travel: In contrast, <b>South America</b> records a relatively lower passenger count of <b>250,822</b>. This indicates that air travel to and from <b>South America</b> may be less prominent compared to other regions, potentially due to factors such as geographical distance or regional trends.<br>

# %% [markdown]
# ----

# %% [markdown]
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>🎈 Conclusion 🎈</b></div>

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="lefAt"><font color=brown>💬 Key Findings:</font></h3>
#
# * <b>Comprehensive Air Travel Data</b>: The dataset, which provides comprehensive insights into <b>air traffic passenger activity</b>, offers a valuable resource for analyzing trends in the airline industry.<br>
# <br>
# * <b>Diverse Airline Operations</b>: The data showcases the operations of various airlines, encompassing domestic and international flights, and includes details such as passenger counts and pricing categories.<br>
# <br>
# * <b>Key Role of the United States</b>: The <b>United States (US)</b> emerges as a central hub for air travel, with an overwhelming <b>747,120,929</b> passengers.<br>
# <br>
# * <b>International Travel Hubs</b>: Regions like <b>Asia</b> and <b>Europe</b> play pivotal roles in international travel, attracting substantial passenger counts.<br>>br>
#
# * <b>Impact of Pricing Categories</b>: Our analysis reveals that pricing categories may influence passenger counts, with lower fares potentially driving higher passenger numbers.<br>
# <br>
# * <b>Seasonal Air Travel Patterns</b>: Seasonal variations are observed in passenger counts, indicating the influence of holidays and travel seasons.<br>
# <br>
# * <b>Notable Airline Performers</b>: The top-performing airlines are identified, including "<b>United Airlines</b>" and "<b>American Airlines</b>" for domestic flights and "<b>United Airlines - Pre 07/01/2013</b>" for international flights.<br>
# <br>
# * <b>Geographic Preferences</b>: Certain regions are favored by travelers, influencing passenger counts. Geographical factors and regional trends play a role in these preferences.<br>
# <br>
# * <b>Research and Policy Implications</b>: This data is a valuable resource for researchers and analysts interested in understanding <b>electric vehicles</b> and clean energy trends, helping to inform future research and policy decisions.<br>
# <br>
# * <b>Data Source for Exploration</b>: The dataset, available to the public, serves as a valuable source for in-depth exploration of electric vehicle adoption, usage, and environmental impact.<br>

# %% [markdown]
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>References</b></div>

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
#
#
# * Sial, A. H., Rashdi, S. Y. S., & Khan, A. H. (2021). Comparative analysis of data visualization libraries Matplotlib and Seaborn in Python. International Journal, 10(1).
#
# * Sahoo, K., Samal, A. K., Pramanik, J., & Pani, S. K. (2019). Exploratory data analysis using Python. International Journal of Innovative Technology and Exploring Engineering, 8(12), 4727-4735.
#
# * Nongthombam, K., & Sharma, D. (2021). Data Analysis using Python. International Journal of Engineering Research & Technology (IJERT), 10(7).
#
# * <Waskom, M. L. (2021). Seaborn: statistical data visualization. Journal of Open Source Software, 6(60), 3021.

# %% [markdown]
# ---
